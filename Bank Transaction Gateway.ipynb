# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import sys
import random
import smtplib
import openpyxl
import sys
from datetime import date
from datetime import datetime
from openpyxl import load_workbook
wb = load_workbook('PATH TO EXCEL FILE OF USER DATA')
list1=[]

sheet = wb['UserDetails']

c=0
###########################################################################
ws = wb.active
first_column = ws['A']
srno = []
# Print the sr no
for x in range(1,len(first_column)): 
    srno.append(first_column[x].value) 
#print(srno)

first_column = ws['B']
userid = []
# Print the uniue id list
for x in range(1,len(first_column)): 
    userid.append(first_column[x].value) 
#print(userid)
first_column = ws['C']
acno = []
# Print the AC/no
for x in range(1,len(first_column)): 
    acno.append(first_column[x].value) 
#print(acno)
first_column = ws['D']
fullname = []
# Print the Full name
for x in range(1,len(first_column)): 
    fullname.append(first_column[x].value) 
#print(fullname)
first_column = ws['E']
mailid = []
# Print the User email
for x in range(1,len(first_column)): 
    mailid.append(first_column[x].value) 
#print(mailid)
first_column = ws['F']
balance = []
# Print the Ac/balance
for x in range(1,len(first_column)): 
    balance.append(first_column[x].value) 
#print(balance)
first_column = ws['G']
status = []
# Print the Ac/status
for x in range(1,len(first_column)): 
    status.append(first_column[x].value) 
#print(status)
first_column = ws['H']
file = []
# Print the filename
for x in range(1,len(first_column)): 
    file.append(first_column[x].value) 
c=1
########################################################################

nameid = input("Please enter full name or Unique ID : ")
while True:
    
        for i in range(len(fullname)):
            if nameid == fullname[i] or nameid == userid[i]:
                print("---Welcome ",fullname[i],"---")
                index = i
                excel_index=i+2
                break
            else:
                c=c+1
                #print(c)
                continue
                
            
        break
if c>=20:
    print("Invalid User")
    sys.exit()
        
k = 0

for i in range(3):        
    ac = input("Please enter your bank A/c number : ")
    if ac == acno[index] : 
        print("---Welcome---")
        
        k = 0
        break
    else:
        print("Invalid User")
        print("Try again")
    k = 1
    
if k==1:
    print("Invalid User")
    print("Oopps! Your your account is blocked!")
    status[index]="Blocked"
    block='G'+str(excel_index)
    sheet[block].value='Blocked'
    wb.save('PATH TO EXCEL FILE OF USER DATA')
    sys.exit("Transaction is terminated")
           

#############################################################################################################3333

    
    
#####STAGE 2
if (status[index]=="Active"):
    print("Your acount number is ",acno[index])
    otp1=random.randint(1000 , 10000)
    otp=str(otp1)
    print("(OTP generated is : ",end="")   #comment this part in end
    print(otp,")")      #comment this part in end

    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText

    fromad = "SENDER MAIL ID"
    toad = mailid[index]

    msg = MIMEMultipart()

    msg['From'] = fromad
    msg['To'] = toad
    msg['Subject'] = "OTP for bank transaction"

    body = otp
    msg.attach(MIMEText(body,'plain'))

    server = smtplib.SMTP('smtp.gmail.com',port = 587)
    server.starttls()
    server.login(fromad,"PASSWORD")

    text = msg.as_string()
    server.sendmail(fromad,toad,text)
    server.quit

    
    m = 0

    for i in range(3):        
        rec_otp = input("Enter OTP  : ")
        if (rec_otp == otp):
            status[index]="Active"
            block='G'+str(excel_index)
            sheet[block].value='Active'
            wb.save('PATH TO EXCEL FILE OF USER DATA')
            m = 0
            break
        else:
            print("Invalid User")
            print("Try again")
        m = 1
    
    if m == 1:
        #print("Invalid User")
        print("Oopps! Your your account is blocked!")
        status[index]="Blocked"
        block='G'+str(excel_index)
        sheet[block].value='Blocked'
        wb.save('PATH TO EXCEL FILE OF USER DATA')
        sys.exit("Transaction is terminated")


    print("OTP validated")
    print("==================================")
    print("Full name = ",fullname[index])
    print("Ac. No. = ",acno[index])
    print("User ID = ",userid[index])
    print("Account Balance = Rs. ",balance[index])
    print("==================================")

#####STAGE 3

    print(" Select Option")
    print("================")
    print("C   :  Credit")
    print("D   :  Debit ")
    print("================")

    for i in range(3):        
        withdrawl = input("Enter your choice : ")
        withdrawl = withdrawl.upper()
        if (withdrawl == 'C'):
            credit = input("Enter amount to be credited : Rs. ")  
            print("--- Amount Credited !!! ---")
            print("Your total account balance is :Rs.",end=" ")
            print(int(balance[index])+int(credit))
            a=int(balance[index])+int(credit)
            balance[index]=str(a)
            block='F'+str(excel_index)
            sheet[block].value=str(a)
            wb.save('PATH TO EXCEL FILE OF USER DATA')
            print("                ----                      ")
            print("Successful Transaction of Rs. %s completed" %credit)
            print("                ----                      ")
            f = open("PATH TO FOLDER WHERE ACCOUNT STATEMENTS WILL BE STORED"+"\\"+file[index],'a')
            today=date.today()
            now=datetime.now()
            time = (now.strftime("%c"))
            entry1 = ["\n",time,"   Credit  "," : ",credit,"  Total balance"," : ",balance[index]]
            sep = " "
            entry = sep.join(entry1)
            entry = str(entry)
            
            f.write(entry)
            f.close()
            m = 0
            break
        elif (withdrawl == 'D'):
            debit = input("Enter amount to be debited : Rs. ")  
            while True:
                if int(debit)<(int(balance[index])-500):
                    print("--- Amount Debited !!! ---")
                    print("Your total account balance is :Rs.",end=" ")
                    print(int(balance[index])-int(debit))
                    a=int(balance[index])-int(debit)
                    balance[index]=str(a)
                    block='F'+str(excel_index)
                    sheet[block].value=str(a)
                    wb.save('PATH TO EXCEL FILE OF USER DATA')
                    print("                ----                      ")
                    print("Successful Transaction of Rs. %s completed" %debit)
                    print("                ----                      ")
                    f = open("PATH TO FOLDER WHERE ACCOUNT STATEMENTS WILL BE STORED"+"\\"+file[index],'a')
                    today=date.today()
                    now=datetime.now()
                    time = (now.strftime("%c"))
                    entry1 = ["\n",time,"  Debit  "," "," : ",debit," Total balance"," : ",balance[index]]
                    sep=" "
                    entry = sep.join(entry1)
                    entry = str(entry)             
                    f.write(entry)
                    f.close()
                    break
                else:
                    print("Minimum balance required is Rs.500")
                    print("Enter Correct amount")
                    debit = input("Enter amount to be debited : Rs. ")  
            m = 0
            break
        

        else:
        
            print("You Entered wrong choice")
    
        
        m = 1
    
    if m == 1:
        #print("Invalid User")
        print("Oopps! Your your account is blocked!")
        status[index]="Blocked"
        block='G'+str(excel_index)
        sheet[block].value='Blocked'
        wb.save('PATH TO EXCEL FILE OF USER DATA')
        sys.exit("Transaction is terminated")



        



    print("-----------------------------------------------------------------")            
    print("THANK YOU !")          
    print("-----------------------------------------------------------------")        
    mini_statement = input("Do you want mini statement of your account[y/n] : ")
    if mini_statement=="y":
        print("==========================================================================================================")
        print("        Full name = ",fullname[index])
        print("        Ac. No.   = ",acno[index])
        print("      -----------Mini Statement------------    ")
        fo = open("PATH TO FOLDER WHERE ACCOUNT STATEMENTS WILL BE STORED"+"\\"+file[index],"r")
        str1=fo.readlines()
        for i in range(len(str1)):
            print(str1[i])
        fo.close()
        print("=============================================================================================================")
        
        
    else:
        print("Thanks!!")
else:
    print("=====================================================================")
    print("Oops! Your Account is Blocked by bank")
    print("Please contact bank")
    print("=====================================================================")
